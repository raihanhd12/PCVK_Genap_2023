# %% [markdown]
# <a href="https://colab.research.google.com/github/raihanhd12/PCVK_Genap_2023/blob/main/Week1Fix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]

# Baca dan tampilkan image
# Loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url) # Read Image
  image = cv.resize(image, (0,0), fx = 0.5, fy = 0.5) # Resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) # Convert color to RGB
  final_frame = cv.hconcat((image, image_2)) # Concatenate image
  cv2_imshow(final_frame) # Show image
  print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F94BFC03700>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94BF484C70>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94BF476490>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi Image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# Resolusi Image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F95044A9DC0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal ditengah image
image_3[int((tinggi)/2),:] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94BF39EFA0>

# %% [markdown]
# **Pertanyaan** & **Jawaban**
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# *  Dikarenakan tidak perlu melakukan instalasi atau pengaturan yang rumit untuk keperluan pengolahan data dengan menggunakan Python.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# *  1. Numpy = menyediakan fungsi yang siap pakai untuk memudahkan kita melakukan perhitungan saintifik seperti matriks, aljabar, statistik, dan sebagainya.
#
#    2. Pandas = membuat tabel, mengubah dimensi data, mengecek data, dan lain sebagainya.
#
#    3. CV2 = Untuk membaca, menampilkan, dan mengkonversi ke hitam putih sebuah citra.
#
#    4. Skimage = perpustakaan yang mendukung aplikasi pemrosesan gambar
#    5. Matplotlib = ibrary yang lengkap untuk membuat visualisasi statis, animasi, dan interaktif menggunakan Python.
#
# - tidak semua digunakan kecuali cv2
#
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ![image.png](data:image/png;base64,...)
# Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
#
# *   untuk mengubah ukuran gambar agar tidak terlalu besar, pada kode tersebut dikecilkan menjadi 50% dari gambar aslinya
#
# 4. Perhatikan potongan kode progam berikut :
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# *   agar menghasilkan warna putih
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
#
# *   resolusi merupakan kumpulan pixel, jika resolusi gambar yang dihasilkan tinggi maka akan semakin bagus gambar nya karena pixelnya juga banyak, kemudian jika gambar yang dihasilkan rendah maka akan semakin sulit dilihat dikarenakan pixel nya dikit

# %% [markdown]
# # TUGAS

# %%
# No 2
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3v = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3d = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3v[x,int(lebar/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3v))
cv2_imshow(final_frame)

# Membuat garis menyilang menyilang diagonal pada image 
for y in range (int(tinggi)):
  image_3d[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3d[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3d))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94BF3BC880>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94BF3BC8E0>

# %%
# No 3
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3h = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal ditengah image
for x in range (int(tinggi/2)):
  image_3h[int(lebar/2-40),int(x-300)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3h))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94BF3BC9A0>

# %%
# No 4
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3p = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal ditengah image
# cv.rectangle(image_3p,(100,100),(250,250),(255,255,255),-1)

# for x in range (int(tinggi/2)):
#   image_3p[int(lebar/2-90), int (x-300)] = [255,255,255]
# for x in range (int(tinggi/2)):
#   image_3p[int(lebar/2), int (x-300)] = [255,255,255]
# for x in range (int(tinggi/3-5.3)):
#   image_3p[int(x+110), int (lebar/2-100)] = [255,255,255]
# for x in range (int(tinggi/3-5.3)):
#   image_3p[int(x+110), int (lebar/2+42.5)] = [255,255,255]

for y in range(155, 255): 
  for x in range (155, 255):
    image_3p[x, y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3p))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F94B62A09A0>
